# %%
#数据预处理
# %matplotlib inline
import numpy as np
#import torch
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#import missingno as msno

#不加下面这一步进程很容易中断
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
os.environ["OMP_NUM_THREADS"] = '9' 

#---------------------------------------------------
import sklearn
from sklearn import metrics
from sklearn.metrics import RocCurveDisplay
#加载模型：
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn import linear_model

from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB

from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier

#---------------------------
from sklearn.model_selection import GridSearchCV

# %%
#一些函数
# get_train_test
# get_dat->train_model
# model

#获得分折好的数据集
def get_data(data,name):
    train_data = data #train[0] / test[0]
    target_name = name #"y4"
    #读
    df= train_data
    features=df.columns.tolist()
    features.remove( target_name )
    y=df[ target_name ]
    X=df[features].values
    return X,y

# %%
#读取最开始的数据
fpath="./lasso/5_train_liux_subx.xlsx"
df=pd.read_excel(fpath)

# %%
X,y = get_data(df,"随访>=3")

"""
from sklearn.ensemble import RandomForestClassifier
#para = {'criterion': 'entropy', 'max_depth': 12, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20}
para = {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1,  'n_estimators': 8}
model = RandomForestClassifier(**para)
model.fit(X, y)
#"""

#"""
import xgboost as xgb
para = {'max_depth': 2,  'n_estimators': 7,}#'min_child_weight': 0.3, # 'scale_pos_weight': 2.4
model = xgb.XGBClassifier(**para)
model.fit(X, y)
#"""

"""
from sklearn.linear_model import LogisticRegression
para = {'C': 5, 'class_weight': 'balanced', 'penalty': 'l2', 'solver': 'liblinear'}
model = LogisticRegression(**para)
model.fit(X, y)
#"""

# 预测概率
y_probabilities_1 = model.predict_proba(X)


#读取最开始的数据
fpath="./lasso/6_test_liux_subx.xlsx"
df=pd.read_excel(fpath)
X,y = get_data(df,"随访>=3")
y_probabilities_2 = model.predict_proba(X)

# %%
y_probabilities_1[:,1]
y_probabilities_2[:,1]
# Out:
# array([0.20686738, 0.4251113 , 0.21073796, 0.24905178, 0.16759513,
#        0.21073796, 0.5433369 , 0.52716166, 0.4251113 , 0.30586234,
#        0.228622  , 0.21842921, 0.30788636, 0.5243258 , 0.60228914,
#        0.29330626, 0.15923432, 0.44054613, 0.61265486, 0.46375182,
#        0.18718971, 0.43247545, 0.21073796, 0.15294333, 0.41250283,
#        0.13710994, 0.15923432, 0.21842921, 0.3241998 , 0.28350443,
#        0.32428682, 0.40447873, 0.43247545, 0.30788636, 0.5086242 ,
#        0.24905178, 0.30748865, 0.2768416 , 0.16759513, 0.69780046,
#        0.24905178, 0.22622833, 0.27946877, 0.18718971, 0.15923432,
#        0.4251113 , 0.23715433, 0.174895  , 0.75824916, 0.6729846 ,
#        0.13990556, 0.19423304, 0.23715433, 0.10636047, 0.4017421 ,
#        0.40447873, 0.7223781 , 0.17910545], dtype=float32)

# %%
np.concatenate((y_probabilities_1[:,1], y_probabilities_2[:,1]))
# Out:
# array([0.5054743 , 0.5142115 , 0.7051219 , 0.21842921, 0.5142115 ,
#        0.24905178, 0.11310604, 0.67947024, 0.15294333, 0.5433369 ,
#        0.38900265, 0.5243258 , 0.46460536, 0.28350443, 0.37919953,
#        0.20763832, 0.35812107, 0.44107622, 0.5054743 , 0.33860716,
#        0.60228914, 0.42203435, 0.38900265, 0.15923432, 0.15294333,
#        0.5086242 , 0.15923432, 0.39368683, 0.69780046, 0.72968227,
#        0.19423304, 0.52716166, 0.37919953, 0.4251113 , 0.38374242,
#        0.6725901 , 0.67947024, 0.29399657, 0.67947024, 0.5433369 ,
#        0.21504188, 0.40447873, 0.75046057, 0.67947024, 0.5086242 ,
#        0.706011  , 0.15923432, 0.2025747 , 0.46224996, 0.27946877,
#        0.23715433, 0.15923432, 0.24905178, 0.28350443, 0.706011  ,
#        0.16515058, 0.7365229 , 0.64675206, 0.43797177, 0.6900008 ,
#        0.785712  , 0.35249633, 0.20763832, 0.42142534, 0.55955964,
#        0.5282343 , 0.6094687 , 0.40447873, 0.6417216 , 0.61265486,
#        0.6888635 , 0.3101954 , 0.26435632, 0.3967676 , 0.15923432,
#        0.52716166, 0.6177579 , 0.42203435, 0.5595782 , 0.6900008 ,
#        0.75824916, 0.25917596, 0.11310604, 0.4251113 , 0.1454882 ,
#        0.5595782 , 0.34416944, 0.20686738, 0.15923432, 0.49795774,
#        0.48737466, 0.27432603, 0.3101954 , 0.42203435, 0.23715433,
#        0.4017421 , 0.21073796, 0.4251113 , 0.75046057, 0.18421316,
#        0.6094687 , 0.23715433, 0.6750659 , 0.5243258 , 0.35249633,
#        0.47935528, 0.28471622, 0.17310092, 0.34466073, 0.35249633,
#        0.44107622, 0.69780046, 0.29399657, 0.20686738, 0.31693786,
#        0.5168219 , 0.47434825, 0.34416944, 0.21779658, 0.31257883,
#        0.3101954 , 0.35249633, 0.42023525, 0.20686738, 0.33860716,
#        0.5346365 , 0.3829667 , 0.49203932, 0.26141137, 0.44054613,
#        0.3674774 , 0.45816615, 0.46375182, 0.1994793 , 0.52716166,
#        0.6417216 , 0.2025747 , 0.5054743 , 0.46375182, 0.2969038 ,
#        0.1454882 , 0.17745315, 0.52716166, 0.52716166, 0.24905178,
#        0.3241998 , 0.228622  , 0.13710994, 0.3241998 , 0.60228914,
#        0.52716166, 0.21504188, 0.1740591 , 0.43346784, 0.6729846 ,
#        0.3674774 , 0.13710994, 0.16759513, 0.5053881 , 0.23715433,
#        0.20686738, 0.4251113 , 0.21073796, 0.24905178, 0.16759513,
#        0.21073796, 0.5433369 , 0.52716166, 0.4251113 , 0.30586234,
#        0.228622  , 0.21842921, 0.30788636, 0.5243258 , 0.60228914,
#        0.29330626, 0.15923432, 0.44054613, 0.61265486, 0.46375182,
#        0.18718971, 0.43247545, 0.21073796, 0.15294333, 0.41250283,
#        0.13710994, 0.15923432, 0.21842921, 0.3241998 , 0.28350443,
#        0.32428682, 0.40447873, 0.43247545, 0.30788636, 0.5086242 ,
#        0.24905178, 0.30748865, 0.2768416 , 0.16759513, 0.69780046,
#        0.24905178, 0.22622833, 0.27946877, 0.18718971, 0.15923432,
#        0.4251113 , 0.23715433, 0.174895  , 0.75824916, 0.6729846 ,
#        0.13990556, 0.19423304, 0.23715433, 0.10636047, 0.4017421 ,
#        0.40447873, 0.7223781 , 0.17910545], dtype=float32)

# %%
score = np.concatenate((y_probabilities_1[:,1], y_probabilities_2[:,1]))

# %%
score = pd.DataFrame({'score': score})

# %%
score
# Out:
#         score
# 0    0.505474
# 1    0.514211
# 2    0.705122
# 3    0.218429
# 4    0.514211
# ..        ...
# 213  0.106360
# 214  0.401742
# 215  0.404479
# 216  0.722378
# 217  0.179105
#
# [218 rows x 1 columns]

# %%
type(score)
# Out:
# pandas.core.frame.DataFrame

# %%
fpath="./lasso_/label.xlsx"
df_label=pd.read_excel(fpath)

# %%
score = pd.concat([df_label, score], axis=1)
#score[["随访>=3"]] = df_label[["随访>=3"]]
#score.rename(columns={'ID': '随访>=3'}, inplace=True)

# %%
score
# Out:
#      随访>=3     score
# 0        1  0.505474
# 1        0  0.514211
# 2        1  0.705122
# 3        0  0.218429
# 4        1  0.514211
# ..     ...       ...
# 213      0  0.106360
# 214      0  0.401742
# 215      0  0.404479
# 216      1  0.722378
# 217      0  0.179105
#
# [218 rows x 2 columns]

# %%
df1 = score.head(160)
df2 = score.tail(58)

# 设置图形大小
plt.figure(figsize=(10, 6))

# 在df1中，特征值为1的箱图
# 在df1中，特征值为0的箱图
plt.subplot(1, 2, 1)
plt.boxplot([ df1[df1['随访>=3'] == 1]['score'] , df1[df1['随访>=3'] == 0]['score'] ],
           labels=['favourable outcomes', 'unfavourable outcomes'])
plt.xlabel('train')
plt.ylabel('risk score')

# 在df2中，特征值为1的箱图
# 在df2中，特征值为0的箱图
plt.subplot(1, 2, 2)
plt.boxplot([ df2[df2['随访>=3'] == 1]['score'] , df2[df2['随访>=3'] == 0]['score'] ],
           labels=['favourable outcomes', 'unfavourable outcomes'])
plt.xlabel('test')

# 调整布局
plt.tight_layout()

# 显示图形
plt.show()

# %%
#观看score在测试和训练集上的分布（箱
#看score整个的分布


# 画分布条形图
plt.figure(figsize=(8, 4))
sns.histplot(score['score'], bins=20, kde=False, color='skyblue')
plt.title('Distribution Plot')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
fpath_out="./lasso_/XB_score.xlsx"
score.to_excel(fpath_out,index=False)# index=False 避免为索引添加一列特征   #utf_8_sig   utf-8

# %%
#读取最开始的数据
fpath="./data/norm_2_test_img_sub.xlsx"
df=pd.read_excel(fpath)

# %%
need = df.columns.tolist()[]
# Out:
# ['ID',
#  'liu_original_shape_Elongation',
#  'liu_original_shape_Flatness',
#  'liu_original_shape_LeastAxisLength',
#  'liu_original_shape_MajorAxisLength',
#  'liu_original_shape_Maximum2DDiameterColumn',
#  'liu_original_shape_Maximum2DDiameterRow',
#  'liu_original_shape_Maximum2DDiameterSlice',
#  'liu_original_shape_Maximum3DDiameter',
#  'liu_original_shape_MeshVolume',
#  'liu_original_shape_MinorAxisLength',
#  'liu_original_shape_Sphericity',
#  'liu_original_shape_SurfaceArea',
#  'liu_original_shape_SurfaceVolumeRatio',
#  'liu_original_shape_VoxelVolume',
#  'liu_original_firstorder_10Percentile',
#  'liu_original_firstorder_90Percentile',
#  'liu_original_firstorder_Energy',
#  'liu_original_firstorder_Entropy',
#  'liu_original_firstorder_InterquartileRange',
#  'liu_original_firstorder_Kurtosis',
#  'liu_original_firstorder_Maximum',
#  'liu_original_firstorder_MeanAbsoluteDeviation',
#  'liu_original_firstorder_Mean',
#  'liu_original_firstorder_Median',
#  'liu_original_firstorder_Minimum',
#  'liu_original_firstorder_Range',
#  'liu_original_firstorder_RobustMeanAbsoluteDeviation',
#  'liu_original_firstorder_RootMeanSquared',
#  'liu_original_firstorder_Skewness',
#  'liu_original_firstorder_TotalEnergy',
#  'liu_original_firstorder_Uniformity',
#  'liu_original_firstorder_Variance',
#  'liu_original_glcm_Autocorrelation',
#  'liu_original_glcm_ClusterProminence',
#  'liu_original_glcm_ClusterShade',
#  'liu_original_glcm_ClusterTendency',
#  'liu_original_glcm_Contrast',
#  'liu_original_glcm_Correlation',
#  'liu_original_glcm_DifferenceAverage',
#  'liu_original_glcm_DifferenceEntropy',
#  'liu_original_glcm_DifferenceVariance',
#  'liu_original_glcm_Id',
#  'liu_original_glcm_Idm',
#  'liu_original_glcm_Idmn',
#  'liu_original_glcm_Idn',
#  'liu_original_glcm_Imc1',
#  'liu_original_glcm_Imc2',
#  'liu_original_glcm_InverseVariance',
#  'liu_original_glcm_JointAverage',
#  'liu_original_glcm_JointEnergy',
#  'liu_original_glcm_JointEntropy',
#  'liu_original_glcm_MCC',
#  'liu_original_glcm_MaximumProbability',
#  'liu_original_glcm_SumAverage',
#  'liu_original_glcm_SumEntropy',
#  'liu_original_glcm_SumSquares',
#  'liu_original_gldm_DependenceEntropy',
#  'liu_original_gldm_DependenceNonUniformity',
#  'liu_original_gldm_DependenceNonUniformityNormalized',
#  'liu_original_gldm_DependenceVariance',
#  'liu_original_gldm_GrayLevelNonUniformity',
#  'liu_original_gldm_GrayLevelVariance',
#  'liu_original_gldm_HighGrayLevelEmphasis',
#  'liu_original_gldm_LargeDependenceEmphasis',
#  'liu_original_gldm_LargeDependenceHighGrayLevelEmphasis',
#  'liu_original_gldm_LargeDependenceLowGrayLevelEmphasis',
#  'liu_original_gldm_LowGrayLevelEmphasis',
#  'liu_original_gldm_SmallDependenceEmphasis',
#  'liu_original_gldm_SmallDependenceHighGrayLevelEmphasis',
#  'liu_original_gldm_SmallDependenceLowGrayLevelEmphasis',
#  'liu_original_glrlm_GrayLevelNonUniformity',
#  'liu_original_glrlm_GrayLevelNonUniformityNormalized',
#  'liu_original_glrlm_GrayLevelVariance',
#  'liu_original_glrlm_HighGrayLevelRunEmphasis',
#  'liu_original_glrlm_LongRunEmphasis',
#  'liu_original_glrlm_LongRunHighGrayLevelEmphasis',
#  'liu_original_glrlm_LongRunLowGrayLevelEmphasis',
#  'liu_original_glrlm_LowGrayLevelRunEmphasis',
#  'liu_original_glrlm_RunEntropy',
#  'liu_original_glrlm_RunLengthNonUniformity',
#  'liu_original_glrlm_RunLengthNonUniformityNormalized',
#  'liu_original_glrlm_RunPercentage',
#  'liu_original_glrlm_RunVariance',
#  'liu_original_glrlm_ShortRunEmphasis',
#  'liu_original_glrlm_ShortRunHighGrayLevelEmphasis',
#  'liu_original_glrlm_ShortRunLowGrayLevelEmphasis',
#  'liu_original_glszm_GrayLevelNonUniformity',
#  'liu_original_glszm_GrayLevelNonUniformityNormalized',
#  'liu_original_glszm_GrayLevelVariance',
#  'liu_original_glszm_HighGrayLevelZoneEmphasis',
#  'liu_original_glszm_LargeAreaEmphasis',
#  'liu_original_glszm_LargeAreaHighGrayLevelEmphasis',
#  'liu_original_glszm_LargeAreaLowGrayLevelEmphasis',
#  'liu_original_glszm_LowGrayLevelZoneEmphasis',
#  'liu_original_glszm_SizeZoneNonUniformity',
#  'liu_original_glszm_SizeZoneNonUniformityNormalized',
#  'liu_original_glszm_SmallAreaEmphasis',
#  'liu_original_glszm_SmallAreaHighGrayLevelEmphasis',
#  'liu_original_glszm_SmallAreaLowGrayLevelEmphasis',
#  'liu_original_glszm_ZoneEntropy',
#  'liu_original_glszm_ZonePercentage',
#  'liu_original_glszm_ZoneVariance',
#  'liu_original_ngtdm_Busyness',
#  'liu_original_ngtdm_Coarseness',
#  'liu_original_ngtdm_Complexity',
#  'liu_original_ngtdm_Contrast',
#  'liu_original_ngtdm_Strength',
#  'liu_exponential_firstorder_10Percentile',
#  'liu_exponential_firstorder_90Percentile',
#  'liu_exponential_firstorder_Energy',
#  'liu_exponential_firstorder_Entropy',
#  'liu_exponential_firstorder_InterquartileRange',
#  'liu_exponential_firstorder_Kurtosis',
#  'liu_exponential_firstorder_Maximum',
#  'liu_exponential_firstorder_MeanAbsoluteDeviation',
#  'liu_exponential_firstorder_Mean',
#  'liu_exponential_firstorder_Median',
#  'liu_exponential_firstorder_Minimum',
#  'liu_exponential_firstorder_Range',
#  'liu_exponential_firstorder_RobustMeanAbsoluteDeviation',
#  'liu_exponential_firstorder_RootMeanSquared',
#  'liu_exponential_firstorder_Skewness',
#  'liu_exponential_firstorder_TotalEnergy',
#  'liu_exponential_firstorder_Uniformity',
#  'liu_exponential_firstorder_Variance',
#  'liu_exponential_glcm_Autocorrelation',
#  'liu_exponential_glcm_ClusterProminence',
#  'liu_exponential_glcm_ClusterShade',
#  'liu_exponential_glcm_ClusterTendency',
#  'liu_exponential_glcm_Contrast',
#  'liu_exponential_glcm_Correlation',
#  'liu_exponential_glcm_DifferenceAverage',
#  'liu_exponential_glcm_DifferenceEntropy',
#  'liu_exponential_glcm_DifferenceVariance',
#  'liu_exponential_glcm_Id',
#  'liu_exponential_glcm_Idm',
#  'liu_exponential_glcm_Idmn',
#  'liu_exponential_glcm_Idn',
#  'liu_exponential_glcm_Imc1',
#  'liu_exponential_glcm_Imc2',
#  'liu_exponential_glcm_InverseVariance',
#  'liu_exponential_glcm_JointAverage',
#  'liu_exponential_glcm_JointEnergy',
#  'liu_exponential_glcm_JointEntropy',
#  'liu_exponential_glcm_MCC',
#  'liu_exponential_glcm_MaximumProbability',
#  'liu_exponential_glcm_SumAverage',
#  'liu_exponential_glcm_SumEntropy',
#  'liu_exponential_glcm_SumSquares',
#  'liu_exponential_gldm_DependenceEntropy',
#  'liu_exponential_gldm_DependenceNonUniformity',
#  'liu_exponential_gldm_DependenceNonUniformityNormalized',
#  'liu_exponential_gldm_DependenceVariance',
#  'liu_exponential_gldm_GrayLevelNonUniformity',
#  'liu_exponential_gldm_GrayLevelVariance',
#  'liu_exponential_gldm_HighGrayLevelEmphasis',
#  'liu_exponential_gldm_LargeDependenceEmphasis',
#  'liu_exponential_gldm_LargeDependenceHighGrayLevelEmphasis',
#  'liu_exponential_gldm_LargeDependenceLowGrayLevelEmphasis',
#  'liu_exponential_gldm_LowGrayLevelEmphasis',
#  'liu_exponential_gldm_SmallDependenceEmphasis',
#  'liu_exponential_gldm_SmallDependenceHighGrayLevelEmphasis',
#  'liu_exponential_gldm_SmallDependenceLowGrayLevelEmphasis',
#  'liu_exponential_glrlm_GrayLevelNonUniformity',
#  'liu_exponential_glrlm_GrayLevelNonUniformityNormalized',
#  'liu_exponential_glrlm_GrayLevelVariance',
#  'liu_exponential_glrlm_HighGrayLevelRunEmphasis',
#  'liu_exponential_glrlm_LongRunEmphasis',
#  'liu_exponential_glrlm_LongRunHighGrayLevelEmphasis',
#  'liu_exponential_glrlm_LongRunLowGrayLevelEmphasis',
#  'liu_exponential_glrlm_LowGrayLevelRunEmphasis',
#  'liu_exponential_glrlm_RunEntropy',
#  'liu_exponential_glrlm_RunLengthNonUniformity',
#  'liu_exponential_glrlm_RunLengthNonUniformityNormalized',
#  'liu_exponential_glrlm_RunPercentage',
#  'liu_exponential_glrlm_RunVariance',
#  'liu_exponential_glrlm_ShortRunEmphasis',
#  'liu_exponential_glrlm_ShortRunHighGrayLevelEmphasis',
#  'liu_exponential_glrlm_ShortRunLowGrayLevelEmphasis',
#  'liu_exponential_glszm_GrayLevelNonUniformity',
#  'liu_exponential_glszm_GrayLevelNonUniformityNormalized',
#  'liu_exponential_glszm_GrayLevelVariance',
#  'liu_exponential_glszm_HighGrayLevelZoneEmphasis',
#  'liu_exponential_glszm_LargeAreaEmphasis',
#  'liu_exponential_glszm_LargeAreaHighGrayLevelEmphasis',
#  'liu_exponential_glszm_LargeAreaLowGrayLevelEmphasis',
#  'liu_exponential_glszm_LowGrayLevelZoneEmphasis',
#  'liu_exponential_glszm_SizeZoneNonUniformity',
#  'liu_exponential_glszm_SizeZoneNonUniformityNormalized',
#  'liu_exponential_glszm_SmallAreaEmphasis',
#  'liu_exponential_glszm_SmallAreaHighGrayLevelEmphasis',
#  'liu_exponential_glszm_SmallAreaLowGrayLevelEmphasis',
#  'liu_exponential_glszm_ZoneEntropy',
#  'liu_exponential_glszm_ZonePercentage',
#  'liu_exponential_glszm_ZoneVariance',
#  'liu_exponential_ngtdm_Busyness',
#  'liu_exponential_ngtdm_Coarseness',
#  'liu_exponential_ngtdm_Complexity',
#  'liu_exponential_ngtdm_Contrast',
#  'liu_exponential_ngtdm_Strength',
#  'liu_gradient_firstorder_10Percentile',
#  'liu_gradient_firstorder_90Percentile',
#  'liu_gradient_firstorder_Energy',
#  'liu_gradient_firstorder_Entropy',
#  'liu_gradient_firstorder_InterquartileRange',
#  'liu_gradient_firstorder_Kurtosis',
#  'liu_gradient_firstorder_Maximum',
#  'liu_gradient_firstorder_MeanAbsoluteDeviation',
#  'liu_gradient_firstorder_Mean',
#  'liu_gradient_firstorder_Median',
#  'liu_gradient_firstorder_Minimum',
#  'liu_gradient_firstorder_Range',
#  'liu_gradient_firstorder_RobustMeanAbsoluteDeviation',
#  'liu_gradient_firstorder_RootMeanSquared',
#  'liu_gradient_firstorder_Skewness',
#  'liu_gradient_firstorder_TotalEnergy',
#  'liu_gradient_firstorder_Uniformity',
#  'liu_gradient_firstorder_Variance',
#  'liu_gradient_glcm_Autocorrelation',
#  'liu_gradient_glcm_ClusterProminence',
#  'liu_gradient_glcm_ClusterShade',
#  'liu_gradient_glcm_ClusterTendency',
#  'liu_gradient_glcm_Contrast',
#  'liu_gradient_glcm_Correlation',
#  'liu_gradient_glcm_DifferenceAverage',
#  'liu_gradient_glcm_DifferenceEntropy',
#  'liu_gradient_glcm_DifferenceVariance',
#  'liu_gradient_glcm_Id',
#  'liu_gradient_glcm_Idm',
#  'liu_gradient_glcm_Idmn',
#  'liu_gradient_glcm_Idn',
#  'liu_gradient_glcm_Imc1',
#  'liu_gradient_glcm_Imc2',
#  'liu_gradient_glcm_InverseVariance',
#  'liu_gradient_glcm_JointAverage',
#  'liu_gradient_glcm_JointEnergy',
#  'liu_gradient_glcm_JointEntropy',
#  'liu_gradient_glcm_MCC',
#  'liu_gradient_glcm_MaximumProbability',
#  'liu_gradient_glcm_SumAverage',
#  'liu_gradient_glcm_SumEntropy',
#  'liu_gradient_glcm_SumSquares',
#  'liu_gradient_gldm_DependenceEntropy',
#  'liu_gradient_gldm_DependenceNonUniformity',
#  'liu_gradient_gldm_DependenceNonUniformityNormalized',
#  'liu_gradient_gldm_DependenceVariance',
#  'liu_gradient_gldm_GrayLevelNonUniformity',
#  'liu_gradient_gldm_GrayLevelVariance',
#  'liu_gradient_gldm_HighGrayLevelEmphasis',
#  'liu_gradient_gldm_LargeDependenceEmphasis',
#  'liu_gradient_gldm_LargeDependenceHighGrayLevelEmphasis',
#  'liu_gradient_gldm_LargeDependenceLowGrayLevelEmphasis',
#  'liu_gradient_gldm_LowGrayLevelEmphasis',
#  'liu_gradient_gldm_SmallDependenceEmphasis',
#  'liu_gradient_gldm_SmallDependenceHighGrayLevelEmphasis',
#  'liu_gradient_gldm_SmallDependenceLowGrayLevelEmphasis',
#  'liu_gradient_glrlm_GrayLevelNonUniformity',
#  'liu_gradient_glrlm_GrayLevelNonUniformityNormalized',
#  'liu_gradient_glrlm_GrayLevelVariance',
#  'liu_gradient_glrlm_HighGrayLevelRunEmphasis',
#  'liu_gradient_glrlm_LongRunEmphasis',
#  'liu_gradient_glrlm_LongRunHighGrayLevelEmphasis',
#  'liu_gradient_glrlm_LongRunLowGrayLevelEmphasis',
#  'liu_gradient_glrlm_LowGrayLevelRunEmphasis',
#  'liu_gradient_glrlm_RunEntropy',
#  'liu_gradient_glrlm_RunLengthNonUniformity',
#  'liu_gradient_glrlm_RunLengthNonUniformityNormalized',
#  'liu_gradient_glrlm_RunPercentage',
#  'liu_gradient_glrlm_RunVariance',
#  'liu_gradient_glrlm_ShortRunEmphasis',
#  'liu_gradient_glrlm_ShortRunHighGrayLevelEmphasis',
#  'liu_gradient_glrlm_ShortRunLowGrayLevelEmphasis',
#  'liu_gradient_glszm_GrayLevelNonUniformity',
#  'liu_gradient_glszm_GrayLevelNonUniformityNormalized',
#  'liu_gradient_glszm_GrayLevelVariance',
#  'liu_gradient_glszm_HighGrayLevelZoneEmphasis',
#  'liu_gradient_glszm_LargeAreaEmphasis',
#  'liu_gradient_glszm_LargeAreaHighGrayLevelEmphasis',
#  'liu_gradient_glszm_LargeAreaLowGrayLevelEmphasis',
#  'liu_gradient_glszm_LowGrayLevelZoneEmphasis',
#  'liu_gradient_glszm_SizeZoneNonUniformity',
#  'liu_gradient_glszm_SizeZoneNonUniformityNormalized',
#  'liu_gradient_glszm_SmallAreaEmphasis',
#  'liu_gradient_glszm_SmallAreaHighGrayLevelEmphasis',
#  'liu_gradient_glszm_SmallAreaLowGrayLevelEmphasis',
#  'liu_gradient_glszm_ZoneEntropy',
#  'liu_gradient_glszm_ZonePercentage',
#  'liu_gradient_glszm_ZoneVariance',
#  'liu_gradient_ngtdm_Busyness',
#  'liu_gradient_ngtdm_Coarseness',
#  'liu_gradient_ngtdm_Complexity',
#  'liu_gradient_ngtdm_Contrast',
#  'liu_gradient_ngtdm_Strength',
#  'liu_lbp-2D_firstorder_10Percentile',
#  'liu_lbp-2D_firstorder_90Percentile',
#  'liu_lbp-2D_firstorder_Energy',
#  'liu_lbp-2D_firstorder_Entropy',
#  'liu_lbp-2D_firstorder_InterquartileRange',
#  'liu_lbp-2D_firstorder_Kurtosis',
#  'liu_lbp-2D_firstorder_Maximum',
#  'liu_lbp-2D_firstorder_MeanAbsoluteDeviation',
#  'liu_lbp-2D_firstorder_Mean',
#  'liu_lbp-2D_firstorder_Median',
#  'liu_lbp-2D_firstorder_Minimum',
#  'liu_lbp-2D_firstorder_Range',
#  'liu_lbp-2D_firstorder_RobustMeanAbsoluteDeviation',
#  'liu_lbp-2D_firstorder_RootMeanSquared',
#  'liu_lbp-2D_firstorder_Skewness',
#  'liu_lbp-2D_firstorder_TotalEnergy',
#  'liu_lbp-2D_firstorder_Uniformity',
#  'liu_lbp-2D_firstorder_Variance',
#  'liu_lbp-2D_glcm_Autocorrelation',
#  'liu_lbp-2D_glcm_ClusterProminence',
#  'liu_lbp-2D_glcm_ClusterShade',
#  'liu_lbp-2D_glcm_ClusterTendency',
#  'liu_lbp-2D_glcm_Contrast',
#  'liu_lbp-2D_glcm_Correlation',
#  'liu_lbp-2D_glcm_DifferenceAverage',
#  'liu_lbp-2D_glcm_DifferenceEntropy',
#  'liu_lbp-2D_glcm_DifferenceVariance',
#  'liu_lbp-2D_glcm_Id',
#  'liu_lbp-2D_glcm_Idm',
#  'liu_lbp-2D_glcm_Idmn',
#  'liu_lbp-2D_glcm_Idn',
#  'liu_lbp-2D_glcm_Imc1',
#  'liu_lbp-2D_glcm_Imc2',
#  'liu_lbp-2D_glcm_InverseVariance',
#  'liu_lbp-2D_glcm_JointAverage',
#  'liu_lbp-2D_glcm_JointEnergy',
#  'liu_lbp-2D_glcm_JointEntropy',
#  'liu_lbp-2D_glcm_MCC',
#  'liu_lbp-2D_glcm_MaximumProbability',
#  'liu_lbp-2D_glcm_SumAverage',
#  'liu_lbp-2D_glcm_SumEntropy',
#  'liu_lbp-2D_glcm_SumSquares',
#  'liu_lbp-2D_gldm_DependenceEntropy',
#  'liu_lbp-2D_gldm_DependenceNonUniformity',
#  'liu_lbp-2D_gldm_DependenceNonUniformityNormalized',
#  'liu_lbp-2D_gldm_DependenceVariance',
#  'liu_lbp-2D_gldm_GrayLevelNonUniformity',
#  'liu_lbp-2D_gldm_GrayLevelVariance',
#  'liu_lbp-2D_gldm_HighGrayLevelEmphasis',
#  'liu_lbp-2D_gldm_LargeDependenceEmphasis',
#  'liu_lbp-2D_gldm_LargeDependenceHighGrayLevelEmphasis',
#  'liu_lbp-2D_gldm_LargeDependenceLowGrayLevelEmphasis',
#  'liu_lbp-2D_gldm_LowGrayLevelEmphasis',
#  'liu_lbp-2D_gldm_SmallDependenceEmphasis',
#  'liu_lbp-2D_gldm_SmallDependenceHighGrayLevelEmphasis',
#  'liu_lbp-2D_gldm_SmallDependenceLowGrayLevelEmphasis',
#  'liu_lbp-2D_glrlm_GrayLevelNonUniformity',
#  'liu_lbp-2D_glrlm_GrayLevelNonUniformityNormalized',
#  'liu_lbp-2D_glrlm_GrayLevelVariance',
#  'liu_lbp-2D_glrlm_HighGrayLevelRunEmphasis',
#  'liu_lbp-2D_glrlm_LongRunEmphasis',
#  'liu_lbp-2D_glrlm_LongRunHighGrayLevelEmphasis',
#  'liu_lbp-2D_glrlm_LongRunLowGrayLevelEmphasis',
#  'liu_lbp-2D_glrlm_LowGrayLevelRunEmphasis',
#  'liu_lbp-2D_glrlm_RunEntropy',
#  'liu_lbp-2D_glrlm_RunLengthNonUniformity',
#  'liu_lbp-2D_glrlm_RunLengthNonUniformityNormalized',
#  'liu_lbp-2D_glrlm_RunPercentage',
#  'liu_lbp-2D_glrlm_RunVariance',
#  'liu_lbp-2D_glrlm_ShortRunEmphasis',
#  'liu_lbp-2D_glrlm_ShortRunHighGrayLevelEmphasis',
#  'liu_lbp-2D_glrlm_ShortRunLowGrayLevelEmphasis',
#  'liu_lbp-2D_glszm_GrayLevelNonUniformity',
#  'liu_lbp-2D_glszm_GrayLevelNonUniformityNormalized',
#  'liu_lbp-2D_glszm_GrayLevelVariance',
#  'liu_lbp-2D_glszm_HighGrayLevelZoneEmphasis',
#  'liu_lbp-2D_glszm_LargeAreaEmphasis',
#  'liu_lbp-2D_glszm_LargeAreaHighGrayLevelEmphasis',
#  'liu_lbp-2D_glszm_LargeAreaLowGrayLevelEmphasis',
#  'liu_lbp-2D_glszm_LowGrayLevelZoneEmphasis',
#  'liu_lbp-2D_glszm_SizeZoneNonUniformity',
#  'liu_lbp-2D_glszm_SizeZoneNonUniformityNormalized',
#  'liu_lbp-2D_glszm_SmallAreaEmphasis',
#  'liu_lbp-2D_glszm_SmallAreaHighGrayLevelEmphasis',
#  'liu_lbp-2D_glszm_SmallAreaLowGrayLevelEmphasis',
#  'liu_lbp-2D_glszm_ZoneEntropy',
#  'liu_lbp-2D_glszm_ZonePercentage',
#  'liu_lbp-2D_glszm_ZoneVariance',
#  'liu_lbp-2D_ngtdm_Busyness',
#  'liu_lbp-2D_ngtdm_Coarseness',
#  'liu_lbp-2D_ngtdm_Complexity',
#  'liu_lbp-2D_ngtdm_Contrast',
#  'liu_lbp-2D_ngtdm_Strength',
#  'liu_logarithm_firstorder_10Percentile',
#  'liu_logarithm_firstorder_90Percentile',
#  'liu_logarithm_firstorder_Energy',
#  'liu_logarithm_firstorder_Entropy',
#  'liu_logarithm_firstorder_InterquartileRange',
#  'liu_logarithm_firstorder_Kurtosis',
#  'liu_logarithm_firstorder_Maximum',
#  'liu_logarithm_firstorder_MeanAbsoluteDeviation',
#  'liu_logarithm_firstorder_Mean',
#  'liu_logarithm_firstorder_Median',
#  'liu_logarithm_firstorder_Minimum',
#  'liu_logarithm_firstorder_Range',
#  'liu_logarithm_firstorder_RobustMeanAbsoluteDeviation',
#  'liu_logarithm_firstorder_RootMeanSquared',
#  'liu_logarithm_firstorder_Skewness',
#  'liu_logarithm_firstorder_TotalEnergy',
#  'liu_logarithm_firstorder_Uniformity',
#  'liu_logarithm_firstorder_Variance',
#  'liu_logarithm_glcm_Autocorrelation',
#  'liu_logarithm_glcm_ClusterProminence',
#  'liu_logarithm_glcm_ClusterShade',
#  'liu_logarithm_glcm_ClusterTendency',
#  'liu_logarithm_glcm_Contrast',
#  'liu_logarithm_glcm_Correlation',
#  'liu_logarithm_glcm_DifferenceAverage',
#  'liu_logarithm_glcm_DifferenceEntropy',
#  'liu_logarithm_glcm_DifferenceVariance',
#  'liu_logarithm_glcm_Id',
#  'liu_logarithm_glcm_Idm',
#  'liu_logarithm_glcm_Idmn',
#  'liu_logarithm_glcm_Idn',
#  'liu_logarithm_glcm_Imc1',
#  'liu_logarithm_glcm_Imc2',
#  'liu_logarithm_glcm_InverseVariance',
#  'liu_logarithm_glcm_JointAverage',
#  'liu_logarithm_glcm_JointEnergy',
#  'liu_logarithm_glcm_JointEntropy',
#  'liu_logarithm_glcm_MCC',
#  'liu_logarithm_glcm_MaximumProbability',
#  'liu_logarithm_glcm_SumAverage',
#  'liu_logarithm_glcm_SumEntropy',
#  'liu_logarithm_glcm_SumSquares',
#  'liu_logarithm_gldm_DependenceEntropy',
#  'liu_logarithm_gldm_DependenceNonUniformity',
#  'liu_logarithm_gldm_DependenceNonUniformityNormalized',
#  'liu_logarithm_gldm_DependenceVariance',
#  'liu_logarithm_gldm_GrayLevelNonUniformity',
#  'liu_logarithm_gldm_GrayLevelVariance',
#  'liu_logarithm_gldm_HighGrayLevelEmphasis',
#  'liu_logarithm_gldm_LargeDependenceEmphasis',
#  'liu_logarithm_gldm_LargeDependenceHighGrayLevelEmphasis',
#  'liu_logarithm_gldm_LargeDependenceLowGrayLevelEmphasis',
#  'liu_logarithm_gldm_LowGrayLevelEmphasis',
#  'liu_logarithm_gldm_SmallDependenceEmphasis',
#  'liu_logarithm_gldm_SmallDependenceHighGrayLevelEmphasis',
#  'liu_logarithm_gldm_SmallDependenceLowGrayLevelEmphasis',
#  'liu_logarithm_glrlm_GrayLevelNonUniformity',
#  'liu_logarithm_glrlm_GrayLevelNonUniformityNormalized',
#  'liu_logarithm_glrlm_GrayLevelVariance',
#  'liu_logarithm_glrlm_HighGrayLevelRunEmphasis',
#  'liu_logarithm_glrlm_LongRunEmphasis',
#  'liu_logarithm_glrlm_LongRunHighGrayLevelEmphasis',
#  'liu_logarithm_glrlm_LongRunLowGrayLevelEmphasis',
#  'liu_logarithm_glrlm_LowGrayLevelRunEmphasis',
#  'liu_logarithm_glrlm_RunEntropy',
#  'liu_logarithm_glrlm_RunLengthNonUniformity',
#  'liu_logarithm_glrlm_RunLengthNonUniformityNormalized',
#  'liu_logarithm_glrlm_RunPercentage',
#  'liu_logarithm_glrlm_RunVariance',
#  'liu_logarithm_glrlm_ShortRunEmphasis',
#  'liu_logarithm_glrlm_ShortRunHighGrayLevelEmphasis',
#  'liu_logarithm_glrlm_ShortRunLowGrayLevelEmphasis',
#  'liu_logarithm_glszm_GrayLevelNonUniformity',
#  'liu_logarithm_glszm_GrayLevelNonUniformityNormalized',
#  'liu_logarithm_glszm_GrayLevelVariance',
#  'liu_logarithm_glszm_HighGrayLevelZoneEmphasis',
#  'liu_logarithm_glszm_LargeAreaEmphasis',
#  'liu_logarithm_glszm_LargeAreaHighGrayLevelEmphasis',
#  'liu_logarithm_glszm_LargeAreaLowGrayLevelEmphasis',
#  'liu_logarithm_glszm_LowGrayLevelZoneEmphasis',
#  'liu_logarithm_glszm_SizeZoneNonUniformity',
#  'liu_logarithm_glszm_SizeZoneNonUniformityNormalized',
#  'liu_logarithm_glszm_SmallAreaEmphasis',
#  'liu_logarithm_glszm_SmallAreaHighGrayLevelEmphasis',
#  'liu_logarithm_glszm_SmallAreaLowGrayLevelEmphasis',
#  'liu_logarithm_glszm_ZoneEntropy',
#  'liu_logarithm_glszm_ZonePercentage',
#  'liu_logarithm_glszm_ZoneVariance',
#  'liu_logarithm_ngtdm_Busyness',
#  'liu_logarithm_ngtdm_Coarseness',
#  'liu_logarithm_ngtdm_Complexity',
#  'liu_logarithm_ngtdm_Contrast',
#  'liu_logarithm_ngtdm_Strength',
#  'liu_square_firstorder_10Percentile',
#  'liu_square_firstorder_90Percentile',
#  'liu_square_firstorder_Energy',
#  'liu_square_firstorder_Entropy',
#  'liu_square_firstorder_InterquartileRange',
#  'liu_square_firstorder_Kurtosis',
#  'liu_square_firstorder_Maximum',
#  'liu_square_firstorder_MeanAbsoluteDeviation',
#  'liu_square_firstorder_Mean',
#  'liu_square_firstorder_Median',
#  'liu_square_firstorder_Minimum',
#  'liu_square_firstorder_Range',
#  'liu_square_firstorder_RobustMeanAbsoluteDeviation',
#  'liu_square_firstorder_RootMeanSquared',
#  'liu_square_firstorder_Skewness',
#  'liu_square_firstorder_TotalEnergy',
#  'liu_square_firstorder_Uniformity',
#  'liu_square_firstorder_Variance',
#  'liu_square_glcm_Autocorrelation',
#  'liu_square_glcm_ClusterProminence',
#  'liu_square_glcm_ClusterShade',
#  'liu_square_glcm_ClusterTendency',
#  'liu_square_glcm_Contrast',
#  'liu_square_glcm_Correlation',
#  'liu_square_glcm_DifferenceAverage',
#  'liu_square_glcm_DifferenceEntropy',
#  'liu_square_glcm_DifferenceVariance',
#  'liu_square_glcm_Id',
#  'liu_square_glcm_Idm',
#  'liu_square_glcm_Idmn',
#  'liu_square_glcm_Idn',
#  'liu_square_glcm_Imc1',
#  'liu_square_glcm_Imc2',
#  'liu_square_glcm_InverseVariance',
#  'liu_square_glcm_JointAverage',
#  'liu_square_glcm_JointEnergy',
#  'liu_square_glcm_JointEntropy',
#  'liu_square_glcm_MCC',
#  'liu_square_glcm_MaximumProbability',
#  'liu_square_glcm_SumAverage',
#  'liu_square_glcm_SumEntropy',
#  'liu_square_glcm_SumSquares',
#  'liu_square_gldm_DependenceEntropy',
#  'liu_square_gldm_DependenceNonUniformity',
#  'liu_square_gldm_DependenceNonUniformityNormalized',
#  'liu_square_gldm_DependenceVariance',
#  'liu_square_gldm_GrayLevelNonUniformity',
#  'liu_square_gldm_GrayLevelVariance',
#  'liu_square_gldm_HighGrayLevelEmphasis',
#  'liu_square_gldm_LargeDependenceEmphasis',
#  'liu_square_gldm_LargeDependenceHighGrayLevelEmphasis',
#  'liu_square_gldm_LargeDependenceLowGrayLevelEmphasis',
#  'liu_square_gldm_LowGrayLevelEmphasis',
#  'liu_square_gldm_SmallDependenceEmphasis',
#  'liu_square_gldm_SmallDependenceHighGrayLevelEmphasis',
#  'liu_square_gldm_SmallDependenceLowGrayLevelEmphasis',
#  'liu_square_glrlm_GrayLevelNonUniformity',
#  'liu_square_glrlm_GrayLevelNonUniformityNormalized',
#  'liu_square_glrlm_GrayLevelVariance',
#  'liu_square_glrlm_HighGrayLevelRunEmphasis',
#  'liu_square_glrlm_LongRunEmphasis',
#  'liu_square_glrlm_LongRunHighGrayLevelEmphasis',
#  'liu_square_glrlm_LongRunLowGrayLevelEmphasis',
#  'liu_square_glrlm_LowGrayLevelRunEmphasis',
#  'liu_square_glrlm_RunEntropy',
#  'liu_square_glrlm_RunLengthNonUniformity',
#  'liu_square_glrlm_RunLengthNonUniformityNormalized',
#  'liu_square_glrlm_RunPercentage',
#  'liu_square_glrlm_RunVariance',
#  'liu_square_glrlm_ShortRunEmphasis',
#  'liu_square_glrlm_ShortRunHighGrayLevelEmphasis',
#  'liu_square_glrlm_ShortRunLowGrayLevelEmphasis',
#  'liu_square_glszm_GrayLevelNonUniformity',
#  'liu_square_glszm_GrayLevelNonUniformityNormalized',
#  'liu_square_glszm_GrayLevelVariance',
#  'liu_square_glszm_HighGrayLevelZoneEmphasis',
#  'liu_square_glszm_LargeAreaEmphasis',
#  'liu_square_glszm_LargeAreaHighGrayLevelEmphasis',
#  'liu_square_glszm_LargeAreaLowGrayLevelEmphasis',
#  'liu_square_glszm_LowGrayLevelZoneEmphasis',
#  'liu_square_glszm_SizeZoneNonUniformity',
#  'liu_square_glszm_SizeZoneNonUniformityNormalized',
#  'liu_square_glszm_SmallAreaEmphasis',
#  'liu_square_glszm_SmallAreaHighGrayLevelEmphasis',
#  'liu_square_glszm_SmallAreaLowGrayLevelEmphasis',
#  'liu_square_glszm_ZoneEntropy',
#  'liu_square_glszm_ZonePercentage',
#  'liu_square_glszm_ZoneVariance',
#  'liu_square_ngtdm_Busyness',
#  'liu_square_ngtdm_Coarseness',
#  'liu_square_ngtdm_Complexity',
#  'liu_square_ngtdm_Contrast',
#  'liu_square_ngtdm_Strength',
#  'liu_squareroot_firstorder_10Percentile',
#  'liu_squareroot_firstorder_90Percentile',
#  'liu_squareroot_firstorder_Energy',
#  'liu_squareroot_firstorder_Entropy',
#  'liu_squareroot_firstorder_InterquartileRange',
#  'liu_squareroot_firstorder_Kurtosis',
#  'liu_squareroot_firstorder_Maximum',
#  'liu_squareroot_firstorder_MeanAbsoluteDeviation',
#  'liu_squareroot_firstorder_Mean',
#  'liu_squareroot_firstorder_Median',
#  'liu_squareroot_firstorder_Minimum',
#  'liu_squareroot_firstorder_Range',
#  'liu_squareroot_firstorder_RobustMeanAbsoluteDeviation',
#  'liu_squareroot_firstorder_RootMeanSquared',
#  'liu_squareroot_firstorder_Skewness',
#  'liu_squareroot_firstorder_TotalEnergy',
#  'liu_squareroot_firstorder_Uniformity',
#  'liu_squareroot_firstorder_Variance',
#  'liu_squareroot_glcm_Autocorrelation',
#  'liu_squareroot_glcm_ClusterProminence',
#  'liu_squareroot_glcm_ClusterShade',
#  'liu_squareroot_glcm_ClusterTendency',
#  'liu_squareroot_glcm_Contrast',
#  'liu_squareroot_glcm_Correlation',
#  'liu_squareroot_glcm_DifferenceAverage',
#  'liu_squareroot_glcm_DifferenceEntropy',
#  'liu_squareroot_glcm_DifferenceVariance',
#  'liu_squareroot_glcm_Id',
#  'liu_squareroot_glcm_Idm',
#  'liu_squareroot_glcm_Idmn',
#  'liu_squareroot_glcm_Idn',
#  'liu_squareroot_glcm_Imc1',
#  'liu_squareroot_glcm_Imc2',
#  'liu_squareroot_glcm_InverseVariance',
#  'liu_squareroot_glcm_JointAverage',
#  'liu_squareroot_glcm_JointEnergy',
#  'liu_squareroot_glcm_JointEntropy',
#  'liu_squareroot_glcm_MCC',
#  'liu_squareroot_glcm_MaximumProbability',
#  'liu_squareroot_glcm_SumAverage',
#  'liu_squareroot_glcm_SumEntropy',
#  'liu_squareroot_glcm_SumSquares',
#  'liu_squareroot_gldm_DependenceEntropy',
#  'liu_squareroot_gldm_DependenceNonUniformity',
#  'liu_squareroot_gldm_DependenceNonUniformityNormalized',
#  'liu_squareroot_gldm_DependenceVariance',
#  'liu_squareroot_gldm_GrayLevelNonUniformity',
#  'liu_squareroot_gldm_GrayLevelVariance',
#  'liu_squareroot_gldm_HighGrayLevelEmphasis',
#  'liu_squareroot_gldm_LargeDependenceEmphasis',
#  'liu_squareroot_gldm_LargeDependenceHighGrayLevelEmphasis',
#  'liu_squareroot_gldm_LargeDependenceLowGrayLevelEmphasis',
#  'liu_squareroot_gldm_LowGrayLevelEmphasis',
#  'liu_squareroot_gldm_SmallDependenceEmphasis',
#  'liu_squareroot_gldm_SmallDependenceHighGrayLevelEmphasis',
#  'liu_squareroot_gldm_SmallDependenceLowGrayLevelEmphasis',
#  'liu_squareroot_glrlm_GrayLevelNonUniformity',
#  'liu_squareroot_glrlm_GrayLevelNonUniformityNormalized',
#  'liu_squareroot_glrlm_GrayLevelVariance',
#  'liu_squareroot_glrlm_HighGrayLevelRunEmphasis',
#  'liu_squareroot_glrlm_LongRunEmphasis',
#  'liu_squareroot_glrlm_LongRunHighGrayLevelEmphasis',
#  'liu_squareroot_glrlm_LongRunLowGrayLevelEmphasis',
#  'liu_squareroot_glrlm_LowGrayLevelRunEmphasis',
#  'liu_squareroot_glrlm_RunEntropy',
#  'liu_squareroot_glrlm_RunLengthNonUniformity',
#  'liu_squareroot_glrlm_RunLengthNonUniformityNormalized',
#  'liu_squareroot_glrlm_RunPercentage',
#  'liu_squareroot_glrlm_RunVariance',
#  'liu_squareroot_glrlm_ShortRunEmphasis',
#  'liu_squareroot_glrlm_ShortRunHighGrayLevelEmphasis',
#  'liu_squareroot_glrlm_ShortRunLowGrayLevelEmphasis',
#  'liu_squareroot_glszm_GrayLevelNonUniformity',
#  'liu_squareroot_glszm_GrayLevelNonUniformityNormalized',
#  'liu_squareroot_glszm_GrayLevelVariance',
#  'liu_squareroot_glszm_HighGrayLevelZoneEmphasis',
#  'liu_squareroot_glszm_LargeAreaEmphasis',
#  'liu_squareroot_glszm_LargeAreaHighGrayLevelEmphasis',
#  'liu_squareroot_glszm_LargeAreaLowGrayLevelEmphasis',
#  'liu_squareroot_glszm_LowGrayLevelZoneEmphasis',
#  'liu_squareroot_glszm_SizeZoneNonUniformity',
#  'liu_squareroot_glszm_SizeZoneNonUniformityNormalized',
#  'liu_squareroot_glszm_SmallAreaEmphasis',
#  'liu_squareroot_glszm_SmallAreaHighGrayLevelEmphasis',
#  'liu_squareroot_glszm_SmallAreaLowGrayLevelEmphasis',
#  'liu_squareroot_glszm_ZoneEntropy',
#  'liu_squareroot_glszm_ZonePercentage',
#  'liu_squareroot_glszm_ZoneVariance',
#  'liu_squareroot_ngtdm_Busyness',
#  'liu_squareroot_ngtdm_Coarseness',
#  'liu_squareroot_ngtdm_Complexity',
#  'liu_squareroot_ngtdm_Contrast',
#  'liu_squareroot_ngtdm_Strength',
#  'liu_wavelet-LLH_firstorder_10Percentile',
#  'liu_wavelet-LLH_firstorder_90Percentile',
#  'liu_wavelet-LLH_firstorder_Energy',
#  'liu_wavelet-LLH_firstorder_Entropy',
#  'liu_wavelet-LLH_firstorder_InterquartileRange',
#  'liu_wavelet-LLH_firstorder_Kurtosis',
#  'liu_wavelet-LLH_firstorder_Maximum',
#  'liu_wavelet-LLH_firstorder_MeanAbsoluteDeviation',
#  'liu_wavelet-LLH_firstorder_Mean',
#  'liu_wavelet-LLH_firstorder_Median',
#  'liu_wavelet-LLH_firstorder_Minimum',
#  'liu_wavelet-LLH_firstorder_Range',
#  'liu_wavelet-LLH_firstorder_RobustMeanAbsoluteDeviation',
#  'liu_wavelet-LLH_firstorder_RootMeanSquared',
#  'liu_wavelet-LLH_firstorder_Skewness',
#  'liu_wavelet-LLH_firstorder_TotalEnergy',
#  'liu_wavelet-LLH_firstorder_Uniformity',
#  'liu_wavelet-LLH_firstorder_Variance',
#  'liu_wavelet-LLH_glcm_Autocorrelation',
#  'liu_wavelet-LLH_glcm_ClusterProminence',
#  'liu_wavelet-LLH_glcm_ClusterShade',
#  'liu_wavelet-LLH_glcm_ClusterTendency',
#  'liu_wavelet-LLH_glcm_Contrast',
#  'liu_wavelet-LLH_glcm_Correlation',
#  'liu_wavelet-LLH_glcm_DifferenceAverage',
#  'liu_wavelet-LLH_glcm_DifferenceEntropy',
#  'liu_wavelet-LLH_glcm_DifferenceVariance',
#  'liu_wavelet-LLH_glcm_Id',
#  'liu_wavelet-LLH_glcm_Idm',
#  'liu_wavelet-LLH_glcm_Idmn',
#  'liu_wavelet-LLH_glcm_Idn',
#  'liu_wavelet-LLH_glcm_Imc1',
#  'liu_wavelet-LLH_glcm_Imc2',
#  'liu_wavelet-LLH_glcm_InverseVariance',
#  'liu_wavelet-LLH_glcm_JointAverage',
#  'liu_wavelet-LLH_glcm_JointEnergy',
#  'liu_wavelet-LLH_glcm_JointEntropy',
#  'liu_wavelet-LLH_glcm_MCC',
#  'liu_wavelet-LLH_glcm_MaximumProbability',
#  'liu_wavelet-LLH_glcm_SumAverage',
#  'liu_wavelet-LLH_glcm_SumEntropy',
#  'liu_wavelet-LLH_glcm_SumSquares',
#  'liu_wavelet-LLH_gldm_DependenceEntropy',
#  'liu_wavelet-LLH_gldm_DependenceNonUniformity',
#  'liu_wavelet-LLH_gldm_DependenceNonUniformityNormalized',
#  'liu_wavelet-LLH_gldm_DependenceVariance',
#  'liu_wavelet-LLH_gldm_GrayLevelNonUniformity',
#  'liu_wavelet-LLH_gldm_GrayLevelVariance',
#  'liu_wavelet-LLH_gldm_HighGrayLevelEmphasis',
#  'liu_wavelet-LLH_gldm_LargeDependenceEmphasis',
#  'liu_wavelet-LLH_gldm_LargeDependenceHighGrayLevelEmphasis',
#  'liu_wavelet-LLH_gldm_LargeDependenceLowGrayLevelEmphasis',
#  'liu_wavelet-LLH_gldm_LowGrayLevelEmphasis',
#  'liu_wavelet-LLH_gldm_SmallDependenceEmphasis',
#  'liu_wavelet-LLH_gldm_SmallDependenceHighGrayLevelEmphasis',
#  'liu_wavelet-LLH_gldm_SmallDependenceLowGrayLevelEmphasis',
#  'liu_wavelet-LLH_glrlm_GrayLevelNonUniformity',
#  'liu_wavelet-LLH_glrlm_GrayLevelNonUniformityNormalized',
#  'liu_wavelet-LLH_glrlm_GrayLevelVariance',
#  'liu_wavelet-LLH_glrlm_HighGrayLevelRunEmphasis',
#  'liu_wavelet-LLH_glrlm_LongRunEmphasis',
#  'liu_wavelet-LLH_glrlm_LongRunHighGrayLevelEmphasis',
#  'liu_wavelet-LLH_glrlm_LongRunLowGrayLevelEmphasis',
#  'liu_wavelet-LLH_glrlm_LowGrayLevelRunEmphasis',
#  'liu_wavelet-LLH_glrlm_RunEntropy',
#  'liu_wavelet-LLH_glrlm_RunLengthNonUniformity',
#  'liu_wavelet-LLH_glrlm_RunLengthNonUniformityNormalized',
#  'liu_wavelet-LLH_glrlm_RunPercentage',
#  'liu_wavelet-LLH_glrlm_RunVariance',
#  'liu_wavelet-LLH_glrlm_ShortRunEmphasis',
#  'liu_wavelet-LLH_glrlm_ShortRunHighGrayLevelEmphasis',
#  'liu_wavelet-LLH_glrlm_ShortRunLowGrayLevelEmphasis',
#  'liu_wavelet-LLH_glszm_GrayLevelNonUniformity',
#  'liu_wavelet-LLH_glszm_GrayLevelNonUniformityNormalized',
#  'liu_wavelet-LLH_glszm_GrayLevelVariance',
#  'liu_wavelet-LLH_glszm_HighGrayLevelZoneEmphasis',
#  'liu_wavelet-LLH_glszm_LargeAreaEmphasis',
#  'liu_wavelet-LLH_glszm_LargeAreaHighGrayLevelEmphasis',
#  'liu_wavelet-LLH_glszm_LargeAreaLowGrayLevelEmphasis',
#  'liu_wavelet-LLH_glszm_LowGrayLevelZoneEmphasis',
#  'liu_wavelet-LLH_glszm_SizeZoneNonUniformity',
#  'liu_wavelet-LLH_glszm_SizeZoneNonUniformityNormalized',
#  'liu_wavelet-LLH_glszm_SmallAreaEmphasis',
#  'liu_wavelet-LLH_glszm_SmallAreaHighGrayLevelEmphasis',
#  'liu_wavelet-LLH_glszm_SmallAreaLowGrayLevelEmphasis',
#  'liu_wavelet-LLH_glszm_ZoneEntropy',
#  'liu_wavelet-LLH_glszm_ZonePercentage',
#  'liu_wavelet-LLH_glszm_ZoneVariance',
#  'liu_wavelet-LLH_ngtdm_Busyness',
#  'liu_wavelet-LLH_ngtdm_Coarseness',
#  'liu_wavelet-LLH_ngtdm_Complexity',
#  'liu_wavelet-LLH_ngtdm_Contrast',
#  'liu_wavelet-LLH_ngtdm_Strength',
#  'liu_wavelet-LHL_firstorder_10Percentile',
#  'liu_wavelet-LHL_firstorder_90Percentile',
#  'liu_wavelet-LHL_firstorder_Energy',
#  'liu_wavelet-LHL_firstorder_Entropy',
#  'liu_wavelet-LHL_firstorder_InterquartileRange',
#  'liu_wavelet-LHL_firstorder_Kurtosis',
#  'liu_wavelet-LHL_firstorder_Maximum',
#  'liu_wavelet-LHL_firstorder_MeanAbsoluteDeviation',
#  'liu_wavelet-LHL_firstorder_Mean',
#  'liu_wavelet-LHL_firstorder_Median',
#  'liu_wavelet-LHL_firstorder_Minimum',
#  'liu_wavelet-LHL_firstorder_Range',
#  'liu_wavelet-LHL_firstorder_RobustMeanAbsoluteDeviation',
#  'liu_wavelet-LHL_firstorder_RootMeanSquared',
#  'liu_wavelet-LHL_firstorder_Skewness',
#  'liu_wavelet-LHL_firstorder_TotalEnergy',
#  'liu_wavelet-LHL_firstorder_Uniformity',
#  'liu_wavelet-LHL_firstorder_Variance',
#  'liu_wavelet-LHL_glcm_Autocorrelation',
#  'liu_wavelet-LHL_glcm_ClusterProminence',
#  'liu_wavelet-LHL_glcm_ClusterShade',
#  'liu_wavelet-LHL_glcm_ClusterTendency',
#  'liu_wavelet-LHL_glcm_Contrast',
#  'liu_wavelet-LHL_glcm_Correlation',
#  'liu_wavelet-LHL_glcm_DifferenceAverage',
#  'liu_wavelet-LHL_glcm_DifferenceEntropy',
#  'liu_wavelet-LHL_glcm_DifferenceVariance',
#  'liu_wavelet-LHL_glcm_Id',
#  'liu_wavelet-LHL_glcm_Idm',
#  'liu_wavelet-LHL_glcm_Idmn',
#  'liu_wavelet-LHL_glcm_Idn',
#  'liu_wavelet-LHL_glcm_Imc1',
#  'liu_wavelet-LHL_glcm_Imc2',
#  'liu_wavelet-LHL_glcm_InverseVariance',
#  'liu_wavelet-LHL_glcm_JointAverage',
#  'liu_wavelet-LHL_glcm_JointEnergy',
#  'liu_wavelet-LHL_glcm_JointEntropy',
#  'liu_wavelet-LHL_glcm_MCC',
#  'liu_wavelet-LHL_glcm_MaximumProbability',
#  'liu_wavelet-LHL_glcm_SumAverage',
#  'liu_wavelet-LHL_glcm_SumEntropy',
#  'liu_wavelet-LHL_glcm_SumSquares',
#  'liu_wavelet-LHL_gldm_DependenceEntropy',
#  'liu_wavelet-LHL_gldm_DependenceNonUniformity',
#  'liu_wavelet-LHL_gldm_DependenceNonUniformityNormalized',
#  'liu_wavelet-LHL_gldm_DependenceVariance',
#  'liu_wavelet-LHL_gldm_GrayLevelNonUniformity',
#  'liu_wavelet-LHL_gldm_GrayLevelVariance',
#  'liu_wavelet-LHL_gldm_HighGrayLevelEmphasis',
#  'liu_wavelet-LHL_gldm_LargeDependenceEmphasis',
#  'liu_wavelet-LHL_gldm_LargeDependenceHighGrayLevelEmphasis',
#  'liu_wavelet-LHL_gldm_LargeDependenceLowGrayLevelEmphasis',
#  'liu_wavelet-LHL_gldm_LowGrayLevelEmphasis',
#  'liu_wavelet-LHL_gldm_SmallDependenceEmphasis',
#  'liu_wavelet-LHL_gldm_SmallDependenceHighGrayLevelEmphasis',
#  'liu_wavelet-LHL_gldm_SmallDependenceLowGrayLevelEmphasis',
#  'liu_wavelet-LHL_glrlm_GrayLevelNonUniformity',
#  'liu_wavelet-LHL_glrlm_GrayLevelNonUniformityNormalized',
#  'liu_wavelet-LHL_glrlm_GrayLevelVariance',
#  'liu_wavelet-LHL_glrlm_HighGrayLevelRunEmphasis',
#  'liu_wavelet-LHL_glrlm_LongRunEmphasis',
#  'liu_wavelet-LHL_glrlm_LongRunHighGrayLevelEmphasis',
#  'liu_wavelet-LHL_glrlm_LongRunLowGrayLevelEmphasis',
#  'liu_wavelet-LHL_glrlm_LowGrayLevelRunEmphasis',
#  'liu_wavelet-LHL_glrlm_RunEntropy',
#  'liu_wavelet-LHL_glrlm_RunLengthNonUniformity',
#  'liu_wavelet-LHL_glrlm_RunLengthNonUniformityNormalized',
#  'liu_wavelet-LHL_glrlm_RunPercentage',
#  'liu_wavelet-LHL_glrlm_RunVariance',
#  'liu_wavelet-LHL_glrlm_ShortRunEmphasis',
#  'liu_wavelet-LHL_glrlm_ShortRunHighGrayLevelEmphasis',
#  'liu_wavelet-LHL_glrlm_ShortRunLowGrayLevelEmphasis',
#  'liu_wavelet-LHL_glszm_GrayLevelNonUniformity',
#  'liu_wavelet-LHL_glszm_GrayLevelNonUniformityNormalized',
#  'liu_wavelet-LHL_glszm_GrayLevelVariance',
#  'liu_wavelet-LHL_glszm_HighGrayLevelZoneEmphasis',
#  'liu_wavelet-LHL_glszm_LargeAreaEmphasis',
#  'liu_wavelet-LHL_glszm_LargeAreaHighGrayLevelEmphasis',
#  'liu_wavelet-LHL_glszm_LargeAreaLowGrayLevelEmphasis',
#  'liu_wavelet-LHL_glszm_LowGrayLevelZoneEmphasis',
#  'liu_wavelet-LHL_glszm_SizeZoneNonUniformity',
#  'liu_wavelet-LHL_glszm_SizeZoneNonUniformityNormalized',
#  'liu_wavelet-LHL_glszm_SmallAreaEmphasis',
#  'liu_wavelet-LHL_glszm_SmallAreaHighGrayLevelEmphasis',
#  'liu_wavelet-LHL_glszm_SmallAreaLowGrayLevelEmphasis',
#  'liu_wavelet-LHL_glszm_ZoneEntropy',
#  'liu_wavelet-LHL_glszm_ZonePercentage',
#  'liu_wavelet-LHL_glszm_ZoneVariance',
#  'liu_wavelet-LHL_ngtdm_Busyness',
#  'liu_wavelet-LHL_ngtdm_Coarseness',
#  'liu_wavelet-LHL_ngtdm_Complexity',
#  'liu_wavelet-LHL_ngtdm_Contrast',
#  'liu_wavelet-LHL_ngtdm_Strength',
#  'liu_wavelet-LHH_firstorder_10Percentile',
#  'liu_wavelet-LHH_firstorder_90Percentile',
#  'liu_wavelet-LHH_firstorder_Energy',
#  'liu_wavelet-LHH_firstorder_Entropy',
#  'liu_wavelet-LHH_firstorder_InterquartileRange',
#  'liu_wavelet-LHH_firstorder_Kurtosis',
#  'liu_wavelet-LHH_firstorder_Maximum',
#  'liu_wavelet-LHH_firstorder_MeanAbsoluteDeviation',
#  'liu_wavelet-LHH_firstorder_Mean',
#  'liu_wavelet-LHH_firstorder_Median',
#  'liu_wavelet-LHH_firstorder_Minimum',
#  'liu_wavelet-LHH_firstorder_Range',
#  'liu_wavelet-LHH_firstorder_RobustMeanAbsoluteDeviation',
#  'liu_wavelet-LHH_firstorder_RootMeanSquared',
#  'liu_wavelet-LHH_firstorder_Skewness',
#  'liu_wavelet-LHH_firstorder_TotalEnergy',
#  'liu_wavelet-LHH_firstorder_Uniformity',
#  'liu_wavelet-LHH_firstorder_Variance',
#  'liu_wavelet-LHH_glcm_Autocorrelation',
#  'liu_wavelet-LHH_glcm_ClusterProminence',
#  'liu_wavelet-LHH_glcm_ClusterShade',
#  'liu_wavelet-LHH_glcm_ClusterTendency',
#  'liu_wavelet-LHH_glcm_Contrast',
#  'liu_wavelet-LHH_glcm_Correlation',
#  'liu_wavelet-LHH_glcm_DifferenceAverage',
#  'liu_wavelet-LHH_glcm_DifferenceEntropy',
#  'liu_wavelet-LHH_glcm_DifferenceVariance',
#  'liu_wavelet-LHH_glcm_Id',
#  'liu_wavelet-LHH_glcm_Idm',
#  'liu_wavelet-LHH_glcm_Idmn',
#  'liu_wavelet-LHH_glcm_Idn',
#  'liu_wavelet-LHH_glcm_Imc1',
#  'liu_wavelet-LHH_glcm_Imc2',
#  'liu_wavelet-LHH_glcm_InverseVariance',
#  'liu_wavelet-LHH_glcm_JointAverage',
#  'liu_wavelet-LHH_glcm_JointEnergy',
#  'liu_wavelet-LHH_glcm_JointEntropy',
#  'liu_wavelet-LHH_glcm_MCC',
#  'liu_wavelet-LHH_glcm_MaximumProbability',
#  'liu_wavelet-LHH_glcm_SumAverage',
#  'liu_wavelet-LHH_glcm_SumEntropy',
#  'liu_wavelet-LHH_glcm_SumSquares',
#  'liu_wavelet-LHH_gldm_DependenceEntropy',
#  'liu_wavelet-LHH_gldm_DependenceNonUniformity',
#  'liu_wavelet-LHH_gldm_DependenceNonUniformityNormalized',
#  'liu_wavelet-LHH_gldm_DependenceVariance',
#  'liu_wavelet-LHH_gldm_GrayLevelNonUniformity',
#  'liu_wavelet-LHH_gldm_GrayLevelVariance',
#  'liu_wavelet-LHH_gldm_HighGrayLevelEmphasis',
#  'liu_wavelet-LHH_gldm_LargeDependenceEmphasis',
#  'liu_wavelet-LHH_gldm_LargeDependenceHighGrayLevelEmphasis',
#  'liu_wavelet-LHH_gldm_LargeDependenceLowGrayLevelEmphasis',
#  'liu_wavelet-LHH_gldm_LowGrayLevelEmphasis',
#  'liu_wavelet-LHH_gldm_SmallDependenceEmphasis',
#  'liu_wavelet-LHH_gldm_SmallDependenceHighGrayLevelEmphasis',
#  'liu_wavelet-LHH_gldm_SmallDependenceLowGrayLevelEmphasis',
#  'liu_wavelet-LHH_glrlm_GrayLevelNonUniformity',
#  'liu_wavelet-LHH_glrlm_GrayLevelNonUniformityNormalized',
#  'liu_wavelet-LHH_glrlm_GrayLevelVariance',
#  'liu_wavelet-LHH_glrlm_HighGrayLevelRunEmphasis',
#  'liu_wavelet-LHH_glrlm_LongRunEmphasis',
#  'liu_wavelet-LHH_glrlm_LongRunHighGrayLevelEmphasis',
#  'liu_wavelet-LHH_glrlm_LongRunLowGrayLevelEmphasis',
#  'liu_wavelet-LHH_glrlm_LowGrayLevelRunEmphasis',
#  'liu_wavelet-LHH_glrlm_RunEntropy',
#  'liu_wavelet-LHH_glrlm_RunLengthNonUniformity',
#  'liu_wavelet-LHH_glrlm_RunLengthNonUniformityNormalized',
#  'liu_wavelet-LHH_glrlm_RunPercentage',
#  'liu_wavelet-LHH_glrlm_RunVariance',
#  'liu_wavelet-LHH_glrlm_ShortRunEmphasis',
#  'liu_wavelet-LHH_glrlm_ShortRunHighGrayLevelEmphasis',
#  'liu_wavelet-LHH_glrlm_ShortRunLowGrayLevelEmphasis',
#  'liu_wavelet-LHH_glszm_GrayLevelNonUniformity',
#  'liu_wavelet-LHH_glszm_GrayLevelNonUniformityNormalized',
#  'liu_wavelet-LHH_glszm_GrayLevelVariance',
#  'liu_wavelet-LHH_glszm_HighGrayLevelZoneEmphasis',
#  'liu_wavelet-LHH_glszm_LargeAreaEmphasis',
#  'liu_wavelet-LHH_glszm_LargeAreaHighGrayLevelEmphasis',
#  'liu_wavelet-LHH_glszm_LargeAreaLowGrayLevelEmphasis',
#  'liu_wavelet-LHH_glszm_LowGrayLevelZoneEmphasis',
#  'liu_wavelet-LHH_glszm_SizeZoneNonUniformity',
#  'liu_wavelet-LHH_glszm_SizeZoneNonUniformityNormalized',
#  'liu_wavelet-LHH_glszm_SmallAreaEmphasis',
#  'liu_wavelet-LHH_glszm_SmallAreaHighGrayLevelEmphasis',
#  'liu_wavelet-LHH_glszm_SmallAreaLowGrayLevelEmphasis',
#  'liu_wavelet-LHH_glszm_ZoneEntropy',
#  'liu_wavelet-LHH_glszm_ZonePercentage',
#  'liu_wavelet-LHH_glszm_ZoneVariance',
#  'liu_wavelet-LHH_ngtdm_Busyness',
#  'liu_wavelet-LHH_ngtdm_Coarseness',
#  'liu_wavelet-LHH_ngtdm_Complexity',
#  'liu_wavelet-LHH_ngtdm_Contrast',
#  'liu_wavelet-LHH_ngtdm_Strength',
#  'liu_wavelet-HLL_firstorder_10Percentile',
#  'liu_wavelet-HLL_firstorder_90Percentile',
#  'liu_wavelet-HLL_firstorder_Energy',
#  'liu_wavelet-HLL_firstorder_Entropy',
#  'liu_wavelet-HLL_firstorder_InterquartileRange',
#  'liu_wavelet-HLL_firstorder_Kurtosis',
#  'liu_wavelet-HLL_firstorder_Maximum',
#  'liu_wavelet-HLL_firstorder_MeanAbsoluteDeviation',
#  'liu_wavelet-HLL_firstorder_Mean',
#  'liu_wavelet-HLL_firstorder_Median',
#  'liu_wavelet-HLL_firstorder_Minimum',
#  'liu_wavelet-HLL_firstorder_Range',
#  'liu_wavelet-HLL_firstorder_RobustMeanAbsoluteDeviation',
#  'liu_wavelet-HLL_firstorder_RootMeanSquared',
#  'liu_wavelet-HLL_firstorder_Skewness',
#  'liu_wavelet-HLL_firstorder_TotalEnergy',
#  'liu_wavelet-HLL_firstorder_Uniformity',
#  'liu_wavelet-HLL_firstorder_Variance',
#  'liu_wavelet-HLL_glcm_Autocorrelation',
#  'liu_wavelet-HLL_glcm_ClusterProminence',
#  'liu_wavelet-HLL_glcm_ClusterShade',
#  'liu_wavelet-HLL_glcm_ClusterTendency',
#  'liu_wavelet-HLL_glcm_Contrast',
#  'liu_wavelet-HLL_glcm_Correlation',
#  'liu_wavelet-HLL_glcm_DifferenceAverage',
#  'liu_wavelet-HLL_glcm_DifferenceEntropy',
#  'liu_wavelet-HLL_glcm_DifferenceVariance',
#  'liu_wavelet-HLL_glcm_Id',
#  'liu_wavelet-HLL_glcm_Idm',
#  'liu_wavelet-HLL_glcm_Idmn',
#  'liu_wavelet-HLL_glcm_Idn',
#  'liu_wavelet-HLL_glcm_Imc1',
#  'liu_wavelet-HLL_glcm_Imc2',
#  'liu_wavelet-HLL_glcm_InverseVariance',
#  'liu_wavelet-HLL_glcm_JointAverage',
#  'liu_wavelet-HLL_glcm_JointEnergy',
#  'liu_wavelet-HLL_glcm_JointEntropy',
#  'liu_wavelet-HLL_glcm_MCC',
#  'liu_wavelet-HLL_glcm_MaximumProbability',
#  'liu_wavelet-HLL_glcm_SumAverage',
#  'liu_wavelet-HLL_glcm_SumEntropy',
#  'liu_wavelet-HLL_glcm_SumSquares',
#  'liu_wavelet-HLL_gldm_DependenceEntropy',
#  'liu_wavelet-HLL_gldm_DependenceNonUniformity',
#  'liu_wavelet-HLL_gldm_DependenceNonUniformityNormalized',
#  'liu_wavelet-HLL_gldm_DependenceVariance',
#  'liu_wavelet-HLL_gldm_GrayLevelNonUniformity',
#  'liu_wavelet-HLL_gldm_GrayLevelVariance',
#  'liu_wavelet-HLL_gldm_HighGrayLevelEmphasis',
#  'liu_wavelet-HLL_gldm_LargeDependenceEmphasis',
#  'liu_wavelet-HLL_gldm_LargeDependenceHighGrayLevelEmphasis',
#  'liu_wavelet-HLL_gldm_LargeDependenceLowGrayLevelEmphasis',
#  'liu_wavelet-HLL_gldm_LowGrayLevelEmphasis',
#  'liu_wavelet-HLL_gldm_SmallDependenceEmphasis',
#  'liu_wavelet-HLL_gldm_SmallDependenceHighGrayLevelEmphasis',
#  ...]
